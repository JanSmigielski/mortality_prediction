# %% [markdown]
# # Data Preparation

# %%
import pandas as pd
import os
import numpy as np
import sys
sys.path.insert(0, os.path.abspath("../src"))
from data_preprocessing import (
    suggested_imputations,
    column_deletion,
    imputation,
    encode_categorical,
    high_corr_deletion
)
import time
import warnings
warnings.filterwarnings("ignore")
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler
from ucimlrepo import fetch_ucirepo

def save_object(obj, filename): 
    with open(filename, 'wb') as output: 
        pickle.dump(obj, output, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Data

# %%
support2 = fetch_ucirepo(id=880) 
  
X = support2.data.features 
y = support2.data.targets[['death']] 

data = pd.concat([X, y], axis=1)

print(data)
# Out:
#            age     sex            dzgroup             dzclass  num.co   edu  \
# 0     62.84998    male        Lung Cancer              Cancer       0  11.0
# 1     60.33899  female          Cirrhosis  COPD/CHF/Cirrhosis       2  12.0
# 2     52.74698  female          Cirrhosis  COPD/CHF/Cirrhosis       2  12.0
# 3     42.38498  female        Lung Cancer              Cancer       2  11.0
# 4     79.88495  female  ARF/MOSF w/Sepsis            ARF/MOSF       1   NaN
# ...        ...     ...                ...                 ...     ...   ...
# 9100  66.07300    male  ARF/MOSF w/Sepsis            ARF/MOSF       1   8.0
# 9101  55.15399  female               Coma                Coma       1  11.0
# 9102  70.38196    male  ARF/MOSF w/Sepsis            ARF/MOSF       1   NaN
# 9103  47.01999    male       MOSF w/Malig            ARF/MOSF       1  13.0
# 9104  81.53894  female  ARF/MOSF w/Sepsis            ARF/MOSF       1   8.0
#
#           income  scoma  charges      totcst  ...      crea    sod        ph  \
# 0       $11-$25k    0.0   9715.0         NaN  ...  1.199951  141.0  7.459961
# 1       $11-$25k   44.0  34496.0         NaN  ...  5.500000  132.0  7.250000
# 2     under $11k    0.0  41094.0         NaN  ...  2.000000  134.0  7.459961
# 3     under $11k    0.0   3075.0         NaN  ...  0.799927  139.0       NaN
# 4            NaN   26.0  50127.0         NaN  ...  0.799927  143.0  7.509766
# ...          ...    ...      ...         ...  ...       ...    ...       ...
# 9100         NaN    0.0  52870.0  34329.3125  ...  1.099854  131.0  7.459961
# 9101         NaN   41.0  35377.0  23558.5000  ...  5.899414  135.0  7.289062
# 9102         NaN    0.0  46564.0  31409.0156  ...  2.699707  139.0  7.379883
# 9103         NaN    0.0  58439.0         NaN  ...  3.500000  135.0  7.469727
# 9104    $11-$25k    0.0  15604.0  10605.7578  ...  1.199951  137.0  7.289062
#
#       glucose   bun   urine  adlp  adls     adlsc  death
# 0         NaN   NaN     NaN   7.0   7.0  7.000000      0
# 1         NaN   NaN     NaN   NaN   1.0  1.000000      1
# 2         NaN   NaN     NaN   1.0   0.0  0.000000      1
# 3         NaN   NaN     NaN   0.0   0.0  0.000000      1
# 4         NaN   NaN     NaN   NaN   2.0  2.000000      0
# ...       ...   ...     ...   ...   ...       ...    ...
# 9100    188.0  21.0     NaN   NaN   0.0  0.000000      0
# 9101    190.0  49.0     0.0   NaN   0.0  0.000000      0
# 9102    189.0  60.0  3900.0   NaN   NaN  2.525391      0
# 9103    246.0  55.0     NaN   NaN   0.0  0.000000      1
# 9104    187.0  15.0     NaN   0.0   NaN  0.494751      1
#
# [9105 rows x 43 columns]

# %%
data.columns
# Out:
# Index(['age', 'sex', 'dzgroup', 'dzclass', 'num.co', 'edu', 'income', 'scoma',
#        'charges', 'totcst', 'totmcst', 'avtisst', 'race', 'sps', 'aps',
#        'surv2m', 'surv6m', 'hday', 'diabetes', 'dementia', 'ca', 'prg2m',
#        'prg6m', 'dnr', 'dnrday', 'meanbp', 'wblc', 'hrt', 'resp', 'temp',
#        'pafi', 'alb', 'bili', 'crea', 'sod', 'ph', 'glucose', 'bun', 'urine',
#        'adlp', 'adls', 'adlsc', 'death'],
#       dtype='object')

# %% [markdown]
# # Data Preparation

# %%
(data.isna().sum().sort_values(ascending=False)/9105)*100
# Out:
# adlp        61.954970
# urine       53.399231
# glucose     49.423394
# bun         47.797913
# totmcst     38.165843
# alb         37.034596
# income      32.751236
# adls        31.488193
# bili        28.566722
# pafi        25.535420
# ph          25.085118
# prg2m       18.110928
# edu         17.946183
# prg6m       17.935200
# totcst       9.752883
# wblc         2.328391
# charges      1.889072
# avtisst      0.900604
# crea         0.735859
# race         0.461285
# dnr          0.329489
# dnrday       0.329489
# scoma        0.010983
# sod          0.010983
# sps          0.010983
# meanbp       0.010983
# surv2m       0.010983
# hrt          0.010983
# resp         0.010983
# temp         0.010983
# aps          0.010983
# surv6m       0.010983
# adlsc        0.000000
# age          0.000000
# sex          0.000000
# ca           0.000000
# dementia     0.000000
# diabetes     0.000000
# hday         0.000000
# num.co       0.000000
# dzclass      0.000000
# dzgroup      0.000000
# death        0.000000
# dtype: float64

# %% [markdown]
# ## Dealing with missing values - imputing numbers suggested by the author of the dataset for features with high percentage of missing values

# %% [markdown]
# - Serum albumin (alb)	3.5
# - PaO2/FiO2 ratio (pafi) 	333.3
# - Bilirubin (bili)	1.01
# - Creatinine (crea)	1.01
# - bun	6.51
# - White blood count (wblc)	9 (thousands)
# - Urine output (urine)	2502

# %%
data = suggested_imputations(data)

# %%
(data.isna().sum().sort_values(ascending=False)/9105)*100
# Out:
# adlp        61.954970
# glucose     49.423394
# totmcst     38.165843
# income      32.751236
# adls        31.488193
# ph          25.085118
# prg2m       18.110928
# edu         17.946183
# prg6m       17.935200
# totcst       9.752883
# charges      1.889072
# avtisst      0.900604
# race         0.461285
# dnrday       0.329489
# dnr          0.329489
# resp         0.010983
# temp         0.010983
# hrt          0.010983
# meanbp       0.010983
# sod          0.010983
# surv2m       0.010983
# surv6m       0.010983
# aps          0.010983
# sps          0.010983
# scoma        0.010983
# bun          0.000000
# urine        0.000000
# alb          0.000000
# crea         0.000000
# adlsc        0.000000
# bili         0.000000
# age          0.000000
# pafi         0.000000
# wblc         0.000000
# sex          0.000000
# ca           0.000000
# dementia     0.000000
# diabetes     0.000000
# hday         0.000000
# num.co       0.000000
# dzclass      0.000000
# dzgroup      0.000000
# death        0.000000
# dtype: float64

# %% [markdown]
# ## Dealing with missing values - deleting few columns based on the high percentage of missing values

# %% [markdown]
# Columns we are going to delete:
# - adlp (61.890153%)
# - glucose (49.638793%)
# - totmcst (38.396833%)
# - income (32.568036%)
# - adls (31.509154%)
# - ph (25.472538%)

# %%
columns_to_delete = ['adlp','glucose','totmcst','income','adls','ph']

# %%
data = column_deletion(data,columns_to_delete)

# %%
(data.isna().sum().sort_values(ascending=False)/9105)*100
# Out:
# prg2m       18.110928
# edu         17.946183
# prg6m       17.935200
# totcst       9.752883
# charges      1.889072
# avtisst      0.900604
# race         0.461285
# dnrday       0.329489
# dnr          0.329489
# surv2m       0.010983
# surv6m       0.010983
# hrt          0.010983
# meanbp       0.010983
# sod          0.010983
# resp         0.010983
# temp         0.010983
# aps          0.010983
# sps          0.010983
# scoma        0.010983
# crea         0.000000
# bili         0.000000
# alb          0.000000
# bun          0.000000
# urine        0.000000
# pafi         0.000000
# adlsc        0.000000
# age          0.000000
# ca           0.000000
# wblc         0.000000
# sex          0.000000
# dementia     0.000000
# diabetes     0.000000
# hday         0.000000
# num.co       0.000000
# dzclass      0.000000
# dzgroup      0.000000
# death        0.000000
# dtype: float64

# %% [markdown]
# ## Dealing with missing values - using KNN imputer for numerical values and deleting rows with empty categorical values

# %%
data = imputation(data,5)

# %%
data.isna().sum().sort_values(ascending=False)
# Out:
# age         0
# prg2m       0
# dnr         0
# dnrday      0
# meanbp      0
# wblc        0
# hrt         0
# resp        0
# temp        0
# pafi        0
# alb         0
# bili        0
# crea        0
# sod         0
# bun         0
# urine       0
# adlsc       0
# prg6m       0
# ca          0
# sex         0
# dementia    0
# dzgroup     0
# dzclass     0
# num.co      0
# edu         0
# scoma       0
# charges     0
# totcst      0
# avtisst     0
# race        0
# sps         0
# aps         0
# surv2m      0
# surv6m      0
# hday        0
# diabetes    0
# death       0
# dtype: int64

# %%
data.describe()
# Out:
#                age       num.co          edu        scoma       charges  \
# count  9033.000000  9033.000000  9033.000000  9033.000000  9.033000e+03
# mean     62.677624     1.870475    11.724720    12.020702  6.029233e+04
# std      15.591624     1.346043     3.174467    24.602534  1.024215e+05
# min      18.041990     0.000000     0.000000     0.000000  1.169000e+03
# 25%      52.829990     1.000000    10.000000     0.000000  9.865195e+03
# 50%      64.909000     2.000000    12.000000     0.000000  2.544100e+04
# 75%      74.028990     3.000000    13.000000     9.000000  6.519400e+04
# max     101.847960     9.000000    31.000000   100.000000  1.435423e+06
#
#               totcst      avtisst          sps          aps       surv2m  ...  \
# count    9033.000000  9033.000000  9033.000000  9033.000000  9033.000000  ...
# mean    32756.196504    22.578699    25.503032    37.560943     0.636525  ...
# std     45831.007706    13.185062     9.841931    19.857789     0.247597  ...
# min         0.000000     1.000000     0.199982     0.000000     0.000000  ...
# 25%      6412.289100    12.000000    19.000000    23.000000     0.509888  ...
# 50%     16159.382800    19.500000    23.898438    34.000000     0.715942  ...
# 75%     40000.145200    31.500000    30.199219    48.000000     0.825928  ...
# max    633212.000000    83.000000    99.187500   143.000000     0.969971  ...
#
#               temp         pafi          alb         bili         crea  \
# count  9033.000000  9033.000000  9033.000000  9033.000000  9033.000000
# mean     37.104041   263.550738     3.153353     2.112286     1.763744
# std       1.251305   103.170174     0.744674     4.553252     1.681046
# min      31.699220    12.000000     0.399963     0.099991     0.099991
# 25%      36.195310   180.000000     2.699707     0.599976     0.899902
# 50%      36.695310   276.187500     3.500000     1.010000     1.199951
# 75%      38.195310   333.300000     3.500000     1.299805     1.899902
# max      41.695310   890.375000    29.000000    63.000000    21.500000
#
#                sod          bun        urine        adlsc        death
# count  9033.000000  9033.000000  9033.000000  9033.000000  9033.000000
# mean    137.562781    19.983742  2357.902676     1.885860     0.680726
# std       6.028766    23.249991  1004.200830     2.006140     0.466221
# min     110.000000     1.000000     0.000000     0.000000     0.000000
# 25%     134.000000     6.510000  2080.000000     0.000000     0.000000
# 50%     137.000000     6.510000  2502.000000     1.000000     1.000000
# 75%     141.000000    24.000000  2502.000000     3.000000     1.000000
# max     181.000000   300.000000  9000.000000     7.073242     1.000000
#
# [8 rows x 31 columns]

# %%
data.dtypes
# Out:
# age         float64
# sex          object
# dzgroup      object
# dzclass      object
# num.co      float64
# edu         float64
# scoma       float64
# charges     float64
# totcst      float64
# avtisst     float64
# race         object
# sps         float64
# aps         float64
# surv2m      float64
# surv6m      float64
# hday        float64
# diabetes    float64
# dementia    float64
# ca           object
# prg2m       float64
# prg6m       float64
# dnr          object
# dnrday      float64
# meanbp      float64
# wblc        float64
# hrt         float64
# resp        float64
# temp        float64
# pafi        float64
# alb         float64
# bili        float64
# crea        float64
# sod         float64
# bun         float64
# urine       float64
# adlsc       float64
# death       float64
# dtype: object

# %% [markdown]
# ## Encoding of the categorical columns

# %%
data, label_encoders = encode_categorical(data)

# %%
data
# Out:
#            age  sex  num.co   edu  scoma  charges       totcst    avtisst  \
# 0     62.84998    1     0.0  11.0    0.0   9715.0   8606.34528   7.000000
# 2     52.74698    0     2.0  12.0    0.0  41094.0  33709.64216  13.000000
# 3     42.38498    0     2.0  11.0    0.0   3075.0   2439.67072   7.000000
# 4     79.88495    0     1.0  11.2   26.0  50127.0  36290.29064  18.666656
# 5     93.01599    1     1.0  14.0   55.0   6884.0  24111.78474   5.000000
# ...        ...  ...     ...   ...    ...      ...          ...        ...
# 9100  66.07300    1     1.0   8.0    0.0  52870.0  34329.31250  20.333328
# 9101  55.15399    0     1.0  11.0   41.0  35377.0  23558.50000  18.000000
# 9102  70.38196    1     1.0   9.8    0.0  46564.0  31409.01560  23.000000
# 9103  47.01999    1     1.0  13.0    0.0  58439.0  29165.55154  35.500000
# 9104  81.53894    0     1.0   8.0    0.0  15604.0  10605.75780  13.500000
#
#             sps   aps  ...  dzclass_Cancer  dzclass_Coma  race_black  \
# 0     33.898438  20.0  ...            True         False       False
# 2     20.500000  45.0  ...           False         False       False
# 3     20.097656  19.0  ...            True         False       False
# 4     23.500000  30.0  ...           False         False       False
# 5     19.398438  27.0  ...           False          True       False
# ...         ...   ...  ...             ...           ...         ...
# 9100  16.296875  22.0  ...           False         False       False
# 9101  25.796875  31.0  ...           False          True       False
# 9102  22.699219  39.0  ...           False         False       False
# 9103  40.195312  51.0  ...           False         False       False
# 9104  18.097656   7.0  ...           False         False       False
#
#       race_hispanic  race_other  race_white  ca_no  ca_yes  \
# 0             False        True       False  False   False
# 2             False       False        True   True   False
# 3             False       False        True  False   False
# 4             False       False        True   True   False
# 5             False       False        True   True   False
# ...             ...         ...         ...    ...     ...
# 9100          False       False        True   True   False
# 9101          False       False        True   True   False
# 9102          False       False        True   True   False
# 9103          False       False        True  False    True
# 9104          False       False        True   True   False
#
#       dnr_dnr before sadm  dnr_no dnr
# 0                   False        True
# 2                   False        True
# 3                   False        True
# 4                   False        True
# 5                   False        True
# ...                   ...         ...
# 9100                False        True
# 9101                False        True
# 9102                False        True
# 9103                False       False
# 9104                False        True
#
# [9033 rows x 50 columns]

# %% [markdown]
# ## Deleting high correlated columns with lower information gain

# %%
data, drop_cols = high_corr_deletion(data, 0.75)

# %%
data
# Out:
#            age  sex  num.co   edu  scoma       totcst    avtisst    surv6m  \
# 0     62.84998    1     0.0  11.0    0.0   8606.34528   7.000000  0.036995
# 2     52.74698    0     2.0  12.0    0.0  33709.64216  13.000000  0.664917
# 3     42.38498    0     2.0  11.0    0.0   2439.67072   7.000000  0.411987
# 4     79.88495    0     1.0  11.2   26.0  36290.29064  18.666656  0.532959
# 5     93.01599    1     1.0  14.0   55.0  24111.78474   5.000000  0.214996
# ...        ...  ...     ...   ...    ...          ...        ...       ...
# 9100  66.07300    1     1.0   8.0    0.0  34329.31250  20.333328  0.801880
# 9101  55.15399    0     1.0  11.0   41.0  23558.50000  18.000000  0.485962
# 9102  70.38196    1     1.0   9.8    0.0  31409.01560  23.000000  0.660889
# 9103  47.01999    1     1.0  13.0    0.0  29165.55154  35.500000  0.091995
# 9104  81.53894    0     1.0   8.0    0.0  10605.75780  13.500000  0.776978
#
#       hday  diabetes  ...  dzclass_Cancer  dzclass_Coma  race_black  \
# 0      1.0       0.0  ...            True         False       False
# 2      4.0       0.0  ...           False         False       False
# 3      1.0       0.0  ...            True         False       False
# 4      3.0       0.0  ...           False         False       False
# 5      1.0       0.0  ...           False          True       False
# ...    ...       ...  ...             ...           ...         ...
# 9100  13.0       0.0  ...           False         False       False
# 9101   1.0       0.0  ...           False          True       False
# 9102  18.0       0.0  ...           False         False       False
# 9103  22.0       0.0  ...           False         False       False
# 9104   1.0       1.0  ...           False         False       False
#
#       race_hispanic  race_other  race_white  ca_no  ca_yes  \
# 0             False        True       False  False   False
# 2             False       False        True   True   False
# 3             False       False        True  False   False
# 4             False       False        True   True   False
# 5             False       False        True   True   False
# ...             ...         ...         ...    ...     ...
# 9100          False       False        True   True   False
# 9101          False       False        True   True   False
# 9102          False       False        True   True   False
# 9103          False       False        True  False    True
# 9104          False       False        True   True   False
#
#       dnr_dnr before sadm  dnr_no dnr
# 0                   False        True
# 2                   False        True
# 3                   False        True
# 4                   False        True
# 5                   False        True
# ...                   ...         ...
# 9100                False        True
# 9101                False        True
# 9102                False        True
# 9103                False       False
# 9104                False        True
#
# [9033 rows x 45 columns]

# %%
drop_cols
# Out:
# ['charges', 'sps', 'aps', 'surv2m', 'prg2m']

# %%
data.columns = data.columns.str.replace(r'[<>[\]]', '', regex=True)

# %%
data
# Out:
#            age  sex  num.co   edu  scoma       totcst    avtisst    surv6m  \
# 0     62.84998    1     0.0  11.0    0.0   8606.34528   7.000000  0.036995
# 2     52.74698    0     2.0  12.0    0.0  33709.64216  13.000000  0.664917
# 3     42.38498    0     2.0  11.0    0.0   2439.67072   7.000000  0.411987
# 4     79.88495    0     1.0  11.2   26.0  36290.29064  18.666656  0.532959
# 5     93.01599    1     1.0  14.0   55.0  24111.78474   5.000000  0.214996
# ...        ...  ...     ...   ...    ...          ...        ...       ...
# 9100  66.07300    1     1.0   8.0    0.0  34329.31250  20.333328  0.801880
# 9101  55.15399    0     1.0  11.0   41.0  23558.50000  18.000000  0.485962
# 9102  70.38196    1     1.0   9.8    0.0  31409.01560  23.000000  0.660889
# 9103  47.01999    1     1.0  13.0    0.0  29165.55154  35.500000  0.091995
# 9104  81.53894    0     1.0   8.0    0.0  10605.75780  13.500000  0.776978
#
#       hday  diabetes  ...  dzclass_Cancer  dzclass_Coma  race_black  \
# 0      1.0       0.0  ...            True         False       False
# 2      4.0       0.0  ...           False         False       False
# 3      1.0       0.0  ...            True         False       False
# 4      3.0       0.0  ...           False         False       False
# 5      1.0       0.0  ...           False          True       False
# ...    ...       ...  ...             ...           ...         ...
# 9100  13.0       0.0  ...           False         False       False
# 9101   1.0       0.0  ...           False          True       False
# 9102  18.0       0.0  ...           False         False       False
# 9103  22.0       0.0  ...           False         False       False
# 9104   1.0       1.0  ...           False         False       False
#
#       race_hispanic  race_other  race_white  ca_no  ca_yes  \
# 0             False        True       False  False   False
# 2             False       False        True   True   False
# 3             False       False        True  False   False
# 4             False       False        True   True   False
# 5             False       False        True   True   False
# ...             ...         ...         ...    ...     ...
# 9100          False       False        True   True   False
# 9101          False       False        True   True   False
# 9102          False       False        True   True   False
# 9103          False       False        True  False    True
# 9104          False       False        True   True   False
#
#       dnr_dnr before sadm  dnr_no dnr
# 0                   False        True
# 2                   False        True
# 3                   False        True
# 4                   False        True
# 5                   False        True
# ...                   ...         ...
# 9100                False        True
# 9101                False        True
# 9102                False        True
# 9103                False       False
# 9104                False        True
#
# [9033 rows x 45 columns]

# %%
data_final = data.to_csv('../data/data_final.csv', index = False)

# %% [markdown]
# ### Data is now prepared for modeling
